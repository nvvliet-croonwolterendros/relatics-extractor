# %%
import json

from src.ingestion.relatics_client import RelaticsClient
from src.ingestion.xml_parser import parse_xml

# %%
# load configuration
with open(
    "configuration.json",
    "r",
    encoding="utf-8"
) as file:
    configuration = json.load(file)

# %%
# set element
elements = {
    "eis": "4dfa1495-7a2f-e911-a2d5-00155d641103"
    # "ontwerpprincipe": "b95be017-7a8d-ec11-b687-001dd8d702bc"
}

element = elements["eis"]

# %%
# get data
client = RelaticsClient(
    client_id=configuration["client_id"],
    client_secret=configuration["client_secret"],
    environment=configuration["environment"]
)

# configuration of ref for Eis
parameters = {
    "ConfigurationOfRef": element
}

root = client.get_request(
    workspace_id="210b2918-b359-4892-a23b-bf96ad23d82f",
    operation="dip_data_model_3",
    parameters=parameters
)

# %%
table = "RelationInstances"

# %%
# element df 
df = parse_xml(
    root=root,
    report_part=table
)

print(df.shape)

df.head()
# Out:
# (28146, 10)
#   R1Instance                          R1InstanceID  \
# 0      AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 1      AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 2      AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 3      AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 4      AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
#
#                      RelationInstanceID            R2Instance  \
# 0  0615a391-7f6e-ee11-b6a1-001dd8d702bc      Interpretatie OG
# 1  1115a391-7f6e-ee11-b6a1-001dd8d702bc        Niet behandeld
# 2  164973f8-149f-ee11-b6a6-001dd8d702bf               B-AB500
# 3  21688d68-a42c-ef11-b6ae-001dd8d702bf  Overeengekomen OG/ON
# 4  2315a391-7f6e-ee11-b6a1-001dd8d702bc          Wie doet wat
#
#                            R2InstanceID               R2Element  \
# 0  0415a391-7f6e-ee11-b6a1-001dd8d702bc  [WEG] Interpretatie OG
# 1  a18bc184-6bd5-ea11-a2f0-00155d641104    Geaccepteerd door ON
# 2  a6508da9-7f6e-ee11-b6a1-001dd8d702bc                     Eis
# 3  128bae1b-10d6-ea11-a2f0-00155d641104              SRA status
# 4  1f15a391-7f6e-ee11-b6a1-001dd8d702bc              WieDoetWat
#
#                             R2ElementID Cardinality  \
# 0  e7966525-0239-e911-a2d7-00155d641104         1:1
# 1  70b59d6a-68d5-ea11-a2f0-00155d641104       0:1|1
# 2  4dfa1495-7a2f-e911-a2d5-00155d641103         0:n
# 3  8c35dcb7-68d5-ea11-a2f0-00155d641104         0:1
# 4  9bc9c835-e2a0-ea11-a2ed-00155d641104         0:n
#
#                              RelationID R1Element
# 0  2b36157b-0239-e911-a2d7-00155d641104       Eis
# 1  83194cdb-68d5-ea11-a2f0-00155d641104       Eis
# 2  1731cf9e-0239-e911-a2d7-00155d641104       Eis
# 3  fe161de8-68d5-ea11-a2f0-00155d641104       Eis
# 4  d4ca6056-57bd-eb11-b679-001dd8d702bf       Eis

# %%
# set number of rows
table_length = 50

# file name
file_name = table

# set path
path = f"tests/unit/fixtures/test_transformer/{file_name}.parquet"

# export to parquet
df.head(table_length).to_parquet(path)
