# %%
import json

from src.ingestion.relatics_client import RelaticsClient
from src.ingestion.xml_parser import parse_xml

# %%
# load configuration
with open(
    "configuration.json",
    "r",
    encoding="utf-8"
) as file:
    configuration = json.load(file)

# %%
# set element
elements = {
    # "eis": "4dfa1495-7a2f-e911-a2d5-00155d641103"
    "ontwerpprincipe": "b95be017-7a8d-ec11-b687-001dd8d702bc"
}

element = elements["ontwerpprincipe"]

# %%
# get data
client = RelaticsClient(
    client_id=configuration["client_id"],
    client_secret=configuration["client_secret"],
    environment=configuration["environment"]
)

# configuration of ref for Eis
parameters = {
    "ConfigurationOfRef": element
}

root = client.get_request(
    workspace_id="210b2918-b359-4892-a23b-bf96ad23d82f",
    operation="dip_data_model_3",
    parameters=parameters
)

# %%
table = "RelationInstances"

# %%
# element df 
df = parse_xml(
    root=root,
    report_part=table
)

print(df.shape)

df.head()
# Out:
# (281, 10)
#                              R1Instance                          R1InstanceID  \
# 0  ZKS - Bedieningssysteem sluiscomplex  035c1856-cd15-f011-b6c0-001dd8d702bf
# 1  ZKS - Bedieningssysteem sluiscomplex  035c1856-cd15-f011-b6c0-001dd8d702bf
# 2  ZKS - Bedieningssysteem sluiscomplex  035c1856-cd15-f011-b6c0-001dd8d702bf
# 3  ZKS - Bedieningssysteem sluiscomplex  035c1856-cd15-f011-b6c0-001dd8d702bf
# 4  ZKS - Bedieningssysteem sluiscomplex  035c1856-cd15-f011-b6c0-001dd8d702bf
#
#                      RelationInstanceID  \
# 0  15174303-ce15-f011-b6c0-001dd8d702bf
# 1  26cc9b30-ce15-f011-b6c0-001dd8d702bf
# 2  28902291-cf15-f011-b6c0-001dd8d702bf
# 3  29de0524-ce15-f011-b6c0-001dd8d702bf
# 4  32f39464-cd15-f011-b6c0-001dd8d702bf
#
#                               R2Instance  \
# 0  Patchpaneel 1 apparatenkast bediening
# 1                   BPO Veersemeer zijde
# 2                         KVM extender 5
# 3                       BPO Bediengebouw
# 4                         Vcenter server
#
#                            R2InstanceID          R2Element  \
# 0  13174303-ce15-f011-b6c0-001dd8d702bf  Hardware apparaat
# 1  24cc9b30-ce15-f011-b6c0-001dd8d702bf  Hardware apparaat
# 2  26902291-cf15-f011-b6c0-001dd8d702bf  Hardware apparaat
# 3  27de0524-ce15-f011-b6c0-001dd8d702bf  Hardware apparaat
# 4  30f39464-cd15-f011-b6c0-001dd8d702bf  Hardware apparaat
#
#                             R2ElementID Cardinality  \
# 0  63bb1a6b-7a8d-ec11-b687-001dd8d702bc         0:n
# 1  63bb1a6b-7a8d-ec11-b687-001dd8d702bc         0:n
# 2  63bb1a6b-7a8d-ec11-b687-001dd8d702bc         0:n
# 3  63bb1a6b-7a8d-ec11-b687-001dd8d702bc         0:n
# 4  63bb1a6b-7a8d-ec11-b687-001dd8d702bc         0:n
#
#                              RelationID        R1Element
# 0  e8bc1770-998d-ec11-b687-001dd8d702bc  Ontwerpprincipe
# 1  e8bc1770-998d-ec11-b687-001dd8d702bc  Ontwerpprincipe
# 2  e8bc1770-998d-ec11-b687-001dd8d702bc  Ontwerpprincipe
# 3  e8bc1770-998d-ec11-b687-001dd8d702bc  Ontwerpprincipe
# 4  e8bc1770-998d-ec11-b687-001dd8d702bc  Ontwerpprincipe

# %%
# set number of rows
table_length = 50

# file name
file_name = table

# set path
path = f"tests/unit/fixtures/test_transformer/{file_name}.parquet"

# export to parquet
df.head(table_length).to_parquet(path)
