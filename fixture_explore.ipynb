# %%
import pandas as pd

# %%
RelationInstances = pd.read_parquet("tests/unit/fixtures/test_transformer/RelationInstances.parquet")

# %%
RelationInstances
# Out:
#    R1Instance                          R1InstanceID  \
# 0       AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 1       AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 2       AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 3       AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 4       AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 5       AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 6       AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 7       AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 8       AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 9       AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 10      AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 11      AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 12      AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 13      AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 14      AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 15      AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 16      AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# ...

# %%
Relations = pd.read_parquet("tests/unit/fixtures/test_transformer/Relations.parquet")

# %%
Relations.iloc[25:35,:]
# Out:
#                         Relation Cardinality  \
# 25  Heeft betrekking op SBS Type         0:n
# 26          Heeft contactpersoon         0:1
# 27                Heeft eigenaar         0:n
# 28                Heeft property         0:1
# 29                Heeft property         0:1
# 30                Heeft property         0:1
# 31                Heeft property         0:1
# 32                Heeft property         0:1
# 33                Heeft property         0:1
# 34                Heeft property         0:1
#
#                               RelationID          R2Element  \
# 25  b121dda7-77c1-ec11-b689-001dd8d702bf    ME-Eis-SBS type
# 26  79a4f66f-efa6-e911-a2df-00155d641103                Rol
# 27  d8af7d26-f931-e911-a2d5-00155d641103                Rol
# 28  108e6382-9747-f011-b6c2-001dd8d702bc          SRA Thema
# 29  25e40114-69d5-ea11-a2f0-00155d641104      SMART-analyse
# 30  44b531ee-9aae-ec11-b688-001dd8d702bf               Type
# ...
