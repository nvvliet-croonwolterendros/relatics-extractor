# %%
import pandas as pd

# %%
file_name = "Relations"
path = f"tests/unit/fixtures/test_transformer/{file_name}.parquet"
df = pd.read_parquet(path)

df.head(5)
# Out:
#                    Relation Cardinality                            RelationID  \
# 0               [WEG] Heeft         0:n  70d4bcc7-f731-e911-a2d5-00155d641103
# 1               [WEG] Heeft         1:1  2b36157b-0239-e911-a2d7-00155d641104
# 2      [WEG] Heeft property         0:1  28e40114-69d5-ea11-a2f0-00155d641104
# 3      [WEG] Heeft property         0:1  caf5f4e1-68d5-ea11-a2f0-00155d641104
# 4  [WEG] Heeft voorgestelde         0:1  75edf1cc-7754-e911-a2d8-00155d641103
#
#                 R2Element                           R2ElementID
# 0     [WEG] Commentaar OG  bd935484-852f-e911-a2d5-00155d641103
# 1  [WEG] Interpretatie OG  e7966525-0239-e911-a2d7-00155d641104
# 2     [WEG] SRA status ON  7a4ae8fe-68d5-ea11-a2f0-00155d641104
# 3  [WEG] SMART-analyse OG  3d39b0b0-68d5-ea11-a2f0-00155d641104
# 4     [WEG] Commentaar OG  bd935484-852f-e911-a2d5-00155d641103

# %%
df.iloc[5:10,:].to_dict(orient="list")
# Out:
# {'Relation': ['Bevat (S)', 'Heeft', 'Heeft', 'Heeft', 'Heeft'],
#  'Cardinality': ['0:n', '0:1', '0:n', '0:n', '0:n'],
#  'RelationID': ['1731cf9e-0239-e911-a2d7-00155d641104',
#   'e1ecc874-0759-ee11-b6a0-001dd8d702bf',
#   '1a160899-b699-ea11-a2ec-00155d641103',
#   '73d4bcc7-f731-e911-a2d5-00155d641103',
#   '924d97e4-f731-e911-a2d5-00155d641103'],
#  'R2Element': ['Eis',
#   'Honorering',
#   'Toelichting',
#   'Commentaar',
#   'Verificatievoorschrift'],
#  'R2ElementID': ['4dfa1495-7a2f-e911-a2d5-00155d641103',
#   '2d821dd9-0259-ee11-b6a0-001dd8d702bf',
#   'ae962581-b699-ea11-a2ec-00155d641103',
#   '275a8d8a-852f-e911-a2d5-00155d641103',
#   '7be9db74-892f-e911-a2d5-00155d641103']}
