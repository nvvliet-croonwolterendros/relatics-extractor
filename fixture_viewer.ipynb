# %%
import pandas as pd

# %%
file_name = "RelationInstances"
path = f"tests/unit/fixtures/test_transformer/{file_name}.parquet"
df = pd.read_parquet(path)

df.head(5)
# Out:
#   R1Instance                          R1InstanceID  \
# 0      AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 1      AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 2      AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 3      AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
# 4      AB010  cb14a391-7f6e-ee11-b6a1-001dd8d702bc
#
#                      RelationInstanceID            R2Instance  \
# 0  0615a391-7f6e-ee11-b6a1-001dd8d702bc      Interpretatie OG
# 1  1115a391-7f6e-ee11-b6a1-001dd8d702bc        Niet behandeld
# 2  164973f8-149f-ee11-b6a6-001dd8d702bf               B-AB500
# 3  21688d68-a42c-ef11-b6ae-001dd8d702bf  Overeengekomen OG/ON
# 4  2315a391-7f6e-ee11-b6a1-001dd8d702bc          Wie doet wat
#
#                            R2InstanceID               R2Element Cardinality  \
# 0  0415a391-7f6e-ee11-b6a1-001dd8d702bc  [WEG] Interpretatie OG         1:1
# 1  a18bc184-6bd5-ea11-a2f0-00155d641104    Geaccepteerd door ON       0:1|1
# 2  a6508da9-7f6e-ee11-b6a1-001dd8d702bc                     Eis         0:n
# 3  128bae1b-10d6-ea11-a2f0-00155d641104              SRA status         0:1
# 4  1f15a391-7f6e-ee11-b6a1-001dd8d702bc              WieDoetWat         0:n
#
#   R1Element
# 0       Eis
# 1       Eis
# 2       Eis
# 3       Eis
# 4       Eis

# %%
df.iloc[5:10,:].to_dict(orient="list")
# Out:
# {'R1Instance': ['AB010', 'AB010', 'AB010', 'AB010', 'AB010'],
#  'R1InstanceID': ['cb14a391-7f6e-ee11-b6a1-001dd8d702bc',
#   'cb14a391-7f6e-ee11-b6a1-001dd8d702bc',
#   'cb14a391-7f6e-ee11-b6a1-001dd8d702bc',
#   'cb14a391-7f6e-ee11-b6a1-001dd8d702bc',
#   'cb14a391-7f6e-ee11-b6a1-001dd8d702bc'],
#  'RelationInstanceID': ['25de6afe-149f-ee11-b6a6-001dd8d702bf',
#   '41766704-159f-ee11-b6a6-001dd8d702bf',
#   '6559790b-ab7f-ee11-b6a5-001dd8d702bf',
#   '77be6fc2-34ce-ee11-b6a8-001dd8d702bf',
#   '80756704-159f-ee11-b6a6-001dd8d702bf'],
#  'R2Instance': ['AB200',
#   'B-AB300',
#   'Contractmanager',
#   'ME-Eis-Bedrijfsproces',
#   'AB100'],
#  'R2InstanceID': ['5adf5bd3-7f6e-ee11-b6a1-001dd8d702bc',
#   '1ed53ef1-7f6e-ee11-b6a1-001dd8d702bc',
#   '5aa573e8-e961-ee11-b6a0-001dd8d702bf',
#   '63be6fc2-34ce-ee11-b6a8-001dd8d702bf',
#   'f0ed48e5-7f6e-ee11-b6a1-001dd8d702bc'],
#  'R2Element': ['Eis', 'Eis', 'Rol', 'ME-Eis-Bedrijfsproces', 'Eis'],
#  'Cardinality': ['0:n', '0:n', '0:n', '0:n', '0:n'],
#  'R1Element': ['Eis', 'Eis', 'Eis', 'Eis', 'Eis']}
